# %% [markdown]
# ### KOBUMANZI TRISHIA    M24B23/011

# %%
import pandas as pd

# %% [markdown]
# ### 1.Importing the provided data set

# %%
BikeSales=pd. read_excel("Bike_Sales.xlsx")
BikeSales
# Out:
#              Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0      2017-01-01    1   January  2017            17           Youth (<25)
# 1      2017-01-01    1   January  2017            23           Youth (<25)
# 2      2017-01-01    1   January  2017            33  Young Adults (25-34)
# 3      2017-01-01    1   January  2017            39        Adults (35-64)
# 4      2017-01-01    1   January  2017            42        Adults (35-64)
# ...           ...  ...       ...   ...           ...                   ...
# 113031 2021-12-31   31  December  2021            52        Adults (35-64)
# 113032 2021-12-31   31  December  2021            25  Young Adults (25-34)
# 113033 2021-12-31   31  December  2021            26  Young Adults (25-34)
# 113034 2021-12-31   31  December  2021            33  Young Adults (25-34)
# 113035 2021-12-31   31  December  2021            44        Adults (35-64)
#
# ...

# %% [markdown]
# ### 2.Identifying the data type of each variable

# %%
# How to get the data types
BikeSales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
#Describing the central tendencies
BikeSales.describe()
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2020-01-06 01:36:09.376127744      15.665753    2019.520153
# min              2017-01-01 00:00:00       1.000000    2017.000000
# 25%              2019-01-09 00:00:00       8.000000    2019.000000
# 50%              2019-10-16 00:00:00      16.000000    2019.500000
# 75%              2021-01-28 00:00:00      23.000000    2021.000000
# max              2021-12-31 00:00:00      31.000000    2021.000000
# std                              NaN       8.781567       1.179704
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %% [markdown]
# ### 3.Describing the central tendency of two continuous variables.
# Unit_Price
# Mean=452.938427    Median=24.000000
# Continuous variable Year is not normally distributed because mean>median
#
# Unit_Cost
# Mean=267.296366     Median=9.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 4.Graphs to show the variability on one continous variable and one categorical variable

# %%
#Histogram to show variability on Unit Price
BikeSales['Unit_Price'].hist()
plt.title('Histogram showing Unit_Price')
# Out:
# Text(0.5, 1.0, 'Histogram showing Unit_Price')

# %%
#Bar chat to show variability on Age_Group
sns.countplot(BikeSales['Age_Group'])
plt.title('Bar plot showing Age_Group')
# Out:
# Text(0.5, 1.0, 'Bar plot showing Age_Group')

# %% [markdown]
# ### 5.Visuals to show relationship between two continous variables

# %%
#Scatter plot to show relationship between Unit_Price and Unit_Cost
BikeSales.plot.scatter(x='Unit_Price', y='Unit_Cost', figsize=(10,5), title='Unit_Price'+" VS "+ 'Unit_Cost')
# Out:
# <Axes: title={'center': 'Unit_Price VS Unit_Cost'}, xlabel='Unit_Price', ylabel='Unit_Cost'>

# %% [markdown]
# ### 6.Visuals to show relationship between two categorical variables

# %%
#Generating a cross-tabulation between 'Age_Group' and 'Customer_Gender'
Crosstable=pd.crosstab(index=BikeSales['Age_Group'],columns=BikeSales['Customer_Gender'])
print(Crosstable)
# Out:
# Customer_Gender           F      M
# Age_Group
# Adults (35-64)        27500  28324
# Seniors (64+)           334    396
# Young Adults (25-34)  18724  19930
# Youth (<25)            8166   9662

# %%
#Bar plot to show relationship between Age_Group and Customer_Gender
Crosstable.plot.bar()
# Out:
# <Axes: xlabel='Age_Group'>

# %% [markdown]
# ### 7.Visuals to show relationship between one continuous variable and one categorical variable

# %%
#Box plot to show relationship between Unit_Price and Age_Group.
BikeSales.boxplot(column='Unit_Price', by='Age_Group', figsize=(18,10))
# Out:
# <Axes: title={'center': 'Unit_Price'}, xlabel='Age_Group'>

# %% [markdown]
# ### 8.Statistical tests for questions 5-7

# %% [markdown]
# i.Stastical test for two continuous variables(No.5)

# %% [markdown]
# ii.Statistical test for two categorical variables(No.6)

# %%
#Chi- square test for Crosstable(Age_Group and Customer_Gender)
from scipy.stats import chi2_contingency
Chi_square_result = chi2_contingency(Crosstable)
print(f"The P-value is {Chi_square_result[1]}")
# Out:
# The P-value is 2.1015167519491788e-14

# %% [markdown]
# Since the P-value is less than 0.05,age_group and customer_gender are correlated.

# %% [markdown]
# iii.Statistical test for a categorical variable and a continuous variable(No.7)
